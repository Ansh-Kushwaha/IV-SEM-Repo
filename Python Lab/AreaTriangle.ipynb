# %% [markdown]
# ##4.Write a program to print area of a triangle.

# %%
h = int(input('Enter height: '))
b = int(input('Enter base: '))
area = 1 / 2 * h * b
print('Area of triangle:', area)
# Out:
# Enter height: 5
# Enter base: 4
# Area of triangle: 10.0
