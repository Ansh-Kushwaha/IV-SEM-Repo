# %% [markdown]
# ##6.Write a program to print the given pattern:
# 1
# 22
# 333
# 4444
# 55555

# %%
for i in range(1, 6):
  for j in range(1, i + 1):
    print(i, end = '')
  print()
# Out:
# 1
# 22
# 333
# 4444
# 55555
