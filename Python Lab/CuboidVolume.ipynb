# %% [markdown]
# ##3.Write a program to print volume of cuboid.

# %%
l = int(input('Enter length: '))
b = int(input('Enter width: '))
h = int(input('Enter height: '))
volume = l * b * h
print('Volume of cuboid:', volume)
# Out:
# Enter length: 2
# Enter width: 2
# Enter height: 2
# Volume of cuboid: 8
