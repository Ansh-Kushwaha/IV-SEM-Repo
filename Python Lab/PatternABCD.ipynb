# %% [markdown]
# ##8.Write a program to print the given pattern:
#   A
#   AB
#   ABC
#   ABCD

# %%
for i in range (1, 5):
  for j in range (0, i):
    print(chr(ord('A') + j), end = '')
  print()
# Out:
# A
# AB
# ABC
# ABCD
