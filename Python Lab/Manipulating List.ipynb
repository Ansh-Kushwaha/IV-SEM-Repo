# %% [markdown]
# # Manipulating List

# %%
basket = ['Apple', 'Bun', 'Cola']
crate = ['Egg', 'Fish', 'Grape']

# %%
print('Basket List', basket)
print('Basket Elements: ', len(basket))
# Out:
# Basket List ['Apple', 'Bun', 'Cola']
# Basket Elements:  3

# %%
basket.append('Damson')
print('Appended: ', basket)
print(('Last Item Removed: '), basket.pop())
print('Basket List: ', basket)
# Out:
# Appended:  ['Apple', 'Bun', 'Cola', 'Damson']
# Last Item Removed:  Damson
# Basket List:  ['Apple', 'Bun', 'Cola']

# %%
basket.extend(crate)
print('Extened: ', basket)
del basket[1]
print('Item Removed: ', basket)
del basket[1:3]
print('Slics Removed: ', basket)
# Out:
# Extened:  ['Apple', 'Bun', 'Cola', 'Egg', 'Fish', 'Grape']
# Item Removed:  ['Apple', 'Cola', 'Egg', 'Fish', 'Grape']
# Slics Removed:  ['Apple', 'Fish', 'Grape']
