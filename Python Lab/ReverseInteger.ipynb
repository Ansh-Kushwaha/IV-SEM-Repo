# %% [markdown]
# ##14.Write a program to print reverse an integer.

# %%
n = int(input('Enter a number: '))
m = 0
while n != 0:
  d = n % 10
  m = m * 10 + d
  n = n // 10
print('The number reverse:', m)
# Out:
# Enter a number: 56789
# The number reverse: 98765
