# %% [markdown]
# ##9.Write a program to print the power of X^n.

# %%
def pow(x, n):
  if n < 0:
    return pow(1 / x, -n)
  elif n == 0:
    return 1
  else:
    return x * pow(x, n - 1)

print(pow(3, 3))
# Out:
# 27
