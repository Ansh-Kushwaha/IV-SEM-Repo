# %% [markdown]
# ##13.Write a program to find the given number is even or odd.

# %%
n = int(input('Enter a number: '))

if n % 2 == 0:
  print(n, 'is an even number.')
else:
  print(n, 'is an odd number.')
# Out:
# Enter a number: 12
# 12 is an even number.
