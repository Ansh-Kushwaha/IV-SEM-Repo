# %% [markdown]
# ##5.Write a program to check value of the factorial.

# %%
def fact(n):
  f = 1
  for i in range(1, n + 1):
    f *= i
  return f

n = int(input('Enter a number: '))
print('Factorial of' , n, '=', fact(n))
# Out:
# Enter a number: 5
# Factorial of 5 = 120
