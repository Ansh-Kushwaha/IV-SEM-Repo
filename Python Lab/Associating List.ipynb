# %% [markdown]
# # Associating List
# 1. How elements are associated in Python.
# 2. Write down syntax of del keyord, usage in list?
# 3. How keys() method is used in Python. Write down its syntax.
# 4. Write down syntax of sorted() function.
# 5. Describe following terms in detail : <br>
# a. Variable <br> b. List <br> c. Tuple <br> d. set <br> e. Dictionary

# %%
dict = {'name': 'Bob', 'ref': 'Python', 'sys': 'win'}
print('Dictionary : ', dict)
# Out:
# Dictionary :  {'name': 'Bob', 'ref': 'Python', 'sys': 'win'}

# %%
print('Reference: ', dict['ref'])
# Out:
# Reference:  Python

# %%
print('Keys: ', dict.keys())
# Out:
# Keys:  dict_keys(['name', 'ref', 'sys'])

# %%
del dict['name']
dict['user'] = 'Tom'
print('Dictionary : ', dict)
# Out:
# Dictionary :  {'ref': 'Python', 'sys': 'win', 'user': 'Tom'}

# %%
print('Is there A name Key? : ', 'name' in dict)
# Out:
# Is there A name Key? :  False
